# %%
using JuMP, Gurobi, CSV

# %%
pixels_full = CSV.read("output_ghana_333km.csv", header = 1)
pixelsSize = size(pixels_full)   #tuple representing dimensions of country
xMax = pixelsSize[1]
yMax = pixelsSize[2]
print(xMax, ", ", yMax)

percentage = 0.95
# Out:
# 315, 165
# 0.95

# %%
xMax = 31
yMax = 16
# Out:
# 16

# %%
s = 0

for i in 1:10
    for j in 1:10
        
        println("hey: ", i, ", ", j)
        
        pixels = pixels_full[xMax*(i-1)+1: xMax*i, yMax*(j-1)+1: yMax*j]
        totalPop = sum(sum(pixels[i,j] for i in 1:xMax) for j in 1:yMax)

        model = Model(with_optimizer(Gurobi.Optimizer))

        @variable(model, S[1:xMax, 1:yMax], Bin)   # S[i,j] = 1 if there is a small access pt at (i,j)
        @variable(model, L[1:xMax, 1:yMax], Bin)   # L[i,j] = 1 if there is a large access pt at (i,j)
        @variable(model, R[1:xMax, 1:yMax], Bin);

        TS = sum(sum(S[i,j] for j in 1:yMax) for i in 1:xMax)   # total number of small access pts
        TL = sum(sum(L[i,j] for j in 1:yMax) for i in 1:xMax);  # total number of large access pts

        @objective(model, Min, 150*TS+250*TL);   # minimize total cost of access pts

        ds = 1       # 5
        dl = 4      # 15
        for i in 1:xMax
            for j in 1:yMax
                @constraint(model, R[i,j] <= sum(sum(S[i+dx, j+dy]
                                             for dy in max(trunc(Int, -sqrt(ds^2-dx^2)), 1-j) : min(yMax-j, trunc(Int, sqrt(ds^2-dx^2))))
                                             for dx in max(-ds, 1-i) : min(ds, xMax-i))
                                             # (dx^2 + dy^2 <= ds^2)
                                             +
                                             sum(sum(L[i+dx, j+dy]
                                             for dy in max(trunc(Int, -sqrt(dl^2-dx^2)), 1-j) : min(yMax-j, trunc(Int, sqrt(dl^2-dx^2))))
                                             for dx in max(-dl, 1-i) : min(dl, xMax-i)))
                                             # (dx^2 + dy^2 <= dl^2)
            end
        end         

        @constraint(model, sum(sum(pixels[i,j]*R[i,j] for i in 1:xMax) for j in 1:yMax) >= percentage*totalPop);
        optimize!(model)

        S_opt = value.(S)
        L_opt = value.(L)
        obj_val = objective_value(model)
        s += obj_val

        for m in 1:xMax
            for n in 1:yMax
                if S_opt[m, n] > 0.0
                    println("S: ", xMax*(i-1)+m, ", ", yMax*(j-1)+n)
                end
                if L_opt[m, n] > 0.0
                    println("L: ", xMax*(i-1)+m, ", ", yMax*(j-1)+n)
                end
            end
        end
    end
end
        
println("sum = ", s)
# Out:
# hey: 1, 1
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 1, 2
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 1, 3
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 1, 4
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 1, 5
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 1, 6
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 1, 7
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23618 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+04, 5e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 1500.0000000
# Presolve removed 412 rows and 1262 columns
# Presolve time: 0.01s
# Presolved: 85 rows, 226 columns, 2578 nonzeros
# Found heuristic solution: objective 1400.0000000
# Found heuristic solution: objective 1150.0000000
# Variable types: 0 continuous, 226 integer (226 binary)
#
# Root relaxation: objective 5.454340e+02, 73 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  545.43396    0   14 1150.00000  545.43396  52.6%     -    0s
# H    0     0                     650.0000000  545.43396  16.1%     -    0s
#      0     0  549.14789    0   24  650.00000  549.14789  15.5%     -    0s
#      0     0  549.14789    0   14  650.00000  549.14789  15.5%     -    0s
#      0     0  565.60429    0   26  650.00000  565.60429  13.0%     -    0s
#      0     0     cutoff    0       650.00000  650.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#
# Explored 1 nodes (189 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 650 1150 1250 ... 1750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+02, best bound 6.500000000000e+02, gap 0.0000%
# L: 23, 110
# L: 29, 108
# S: 31, 105
# hey: 1, 8
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23698 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+04, 7e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 2000.0000000
# Presolve removed 332 rows and 1013 columns
# Presolve time: 0.01s
# Presolved: 165 rows, 475 columns, 6045 nonzeros
# Found heuristic solution: objective 3000.0000000
# Found heuristic solution: objective 1800.0000000
# Variable types: 0 continuous, 475 integer (475 binary)
#
# Root relaxation: objective 9.745843e+02, 207 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  974.58430    0   43 1800.00000  974.58430  45.9%     -    0s
# H    0     0                    1300.0000000  974.58430  25.0%     -    0s
# H    0     0                    1000.0000000  974.58430  2.54%     -    0s
#
# Explored 1 nodes (207 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1000 1300 1800 ... 3750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%
# L: 21, 116
# L: 23, 121
# L: 28, 115
# L: 28, 125
# hey: 1, 9
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23551 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+04, 1e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 500.0000000
# Presolve removed 479 rows and 1450 columns
# Presolve time: 0.00s
# Presolved: 18 rows, 38 columns, 251 nonzeros
# Found heuristic solution: objective 400.0000000
# Found heuristic solution: objective 250.0000000
# Variable types: 0 continuous, 38 integer (38 binary)
#
# Root relaxation: cutoff, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       250.00000  250.00000  0.00%     -    0s
#
# Explored 0 nodes (3 simplex iterations) in 0.00 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 250 400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+02, best bound 2.500000000000e+02, gap 0.0000%
# L: 31, 129
# hey: 1, 10
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23543 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+03, 9e+03]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 250.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 250 13000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+02, best bound 2.500000000000e+02, gap 0.0000%
# L: 30, 155
# hey: 2, 1
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23811 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+05, 2e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 3500.0000000
# Presolve removed 219 rows and 687 columns
# Presolve time: 0.02s
# Presolved: 278 rows, 801 columns, 11858 nonzeros
# Found heuristic solution: objective 5600.0000000
# Variable types: 0 continuous, 801 integer (801 binary)
#
# Root relaxation: objective 1.410830e+03, 359 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1410.82975    0   87 3500.00000 1410.82975  59.7%     -    0s
# H    0     0                    2500.0000000 1410.82975  43.6%     -    0s
# H    0     0                    2050.0000000 1410.82975  31.2%     -    0s
# H    0     0                    1750.0000000 1410.82975  19.4%     -    0s
# H    0     0                    1500.0000000 1410.82975  5.94%     -    0s
#      0     0 1413.67241    0   90 1500.00000 1413.67241  5.76%     -    0s
#
# Explored 1 nodes (379 simplex iterations) in 0.17 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1500 1500 1750 ... 6400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+03, best bound 1.500000000000e+03, gap 0.0000%
# L: 43, 14
# L: 47, 8
# L: 50, 15
# L: 53, 8
# L: 58, 13
# L: 59, 7
# hey: 2, 2
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23818 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 2750.0000000
# Presolve removed 212 rows and 651 columns
# Presolve time: 0.02s
# Presolved: 285 rows, 837 columns, 12415 nonzeros
# Found heuristic solution: objective 5400.0000000
# Found heuristic solution: objective 2550.0000000
# Variable types: 0 continuous, 837 integer (837 binary)
#
# Root relaxation: objective 1.608446e+03, 420 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1608.44639    0   55 2550.00000 1608.44639  36.9%     -    0s
# H    0     0                    2200.0000000 1608.44639  26.9%     -    0s
# H    0     0                    1900.0000000 1608.44639  15.3%     -    0s
# H    0     0                    1750.0000000 1608.44639  8.09%     -    0s
#      0     0 1611.53269    0  127 1750.00000 1611.53269  7.91%     -    0s
#      0     0 1611.53269    0   55 1750.00000 1611.53269  7.91%     -    0s
#      0     0 1611.53269    0  127 1750.00000 1611.53269  7.91%     -    0s
#      0     0 1636.39375    0  144 1750.00000 1636.39375  6.49%     -    0s
#      0     0 1637.02344    0  133 1750.00000 1637.02344  6.46%     -    0s
# H    0     0                    1650.0000000 1637.02344  0.79%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 2
#   Zero half: 4
#
# Explored 1 nodes (1000 simplex iterations) in 0.31 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1650 1750 1900 ... 7000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.650000000000e+03, best bound 1.650000000000e+03, gap 0.0000%
# S: 42, 17
# L: 47, 19
# L: 51, 28
# L: 53, 20
# L: 59, 25
# L: 59, 30
# L: 60, 19
# hey: 2, 3
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23740 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+04, 6e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 2500.0000000
# Presolve removed 290 rows and 895 columns
# Presolve time: 0.01s
# Presolved: 207 rows, 593 columns, 8450 nonzeros
# Found heuristic solution: objective 3350.0000000
# Found heuristic solution: objective 2300.0000000
# Variable types: 0 continuous, 593 integer (593 binary)
#
# Root relaxation: objective 1.086869e+03, 290 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1086.86851    0   73 2300.00000 1086.86851  52.7%     -    0s
# H    0     0                    1900.0000000 1086.86851  42.8%     -    0s
# H    0     0                    1650.0000000 1086.86851  34.1%     -    0s
# H    0     0                    1250.0000000 1086.86851  13.1%     -    0s
#      0     0 1147.90958    0   69 1250.00000 1147.90958  8.17%     -    0s
#      0     0 1147.90958    0   73 1250.00000 1147.90958  8.17%     -    0s
#      0     0 1147.96482    0   60 1250.00000 1147.96482  8.16%     -    0s
# H    0     0                    1150.0000000 1147.96482  0.18%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Zero half: 2
#
# Explored 1 nodes (874 simplex iterations) in 0.19 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1150 1250 1650 ... 4500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.150000000000e+03, best bound 1.150000000000e+03, gap 0.0000%
# L: 51, 36
# L: 55, 41
# L: 59, 36
# L: 60, 45
# S: 62, 41
# hey: 2, 4
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23648 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+03, 9e+03]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 2000.0000000
# Presolve removed 382 rows and 1139 columns
# Presolve time: 0.01s
# Presolved: 115 rows, 349 columns, 4108 nonzeros
# Found heuristic solution: objective 1600.0000000
# Variable types: 0 continuous, 349 integer (349 binary)
#
# Root relaxation: objective 7.204259e+02, 131 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  720.42590    0   29 1600.00000  720.42590  55.0%     -    0s
# H    0     0                     750.0000000  720.42590  3.94%     -    0s
#
# Explored 1 nodes (131 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 750 1600 1900 2500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.500000000000e+02, best bound 7.500000000000e+02, gap 0.0000%
# L: 54, 53
# L: 60, 52
# L: 61, 60
# hey: 2, 5
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23559 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+03, 6e+03]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 750.0000000
# Presolve removed 474 rows and 1421 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 67 columns, 493 nonzeros
# Found heuristic solution: objective 550.0000000
# Variable types: 0 continuous, 67 integer (67 binary)
#
# Root relaxation: objective 3.775862e+02, 36 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     400.0000000  400.00000  0.00%     -    0s
#
# Explored 0 nodes (39 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 400 550 750 750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+02, best bound 4.000000000000e+02, gap 0.0000%
# L: 59, 79
# S: 62, 66
# hey: 2, 6
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23870 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 3e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 4000.0000000
# Presolve removed 160 rows and 507 columns
# Presolve time: 0.02s
# Presolved: 337 rows, 981 columns, 14934 nonzeros
# Found heuristic solution: objective 6150.0000000
# Found heuristic solution: objective 3350.0000000
# Variable types: 0 continuous, 981 integer (981 binary)
#
# Root relaxation: objective 1.652622e+03, 470 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1652.62200    0  155 3350.00000 1652.62200  50.7%     -    0s
# H    0     0                    2000.0000000 1652.62200  17.4%     -    0s
# H    0     0                    1750.0000000 1652.62200  5.56%     -    0s
#      0     0 1661.59429    0  163 1750.00000 1661.59429  5.05%     -    0s
#      0     0 1661.59429    0  154 1750.00000 1661.59429  5.05%     -    0s
#      0     0 1663.54645    0  163 1750.00000 1663.54645  4.94%     -    0s
#      0     0     cutoff    0      1750.00000 1750.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 4
#
# Explored 1 nodes (966 simplex iterations) in 0.44 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1750 2000 3350 ... 7750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.750000000000e+03, best bound 1.750000000000e+03, gap 0.0000%
# L: 40, 93
# L: 45, 87
# L: 48, 94
# L: 52, 84
# L: 53, 90
# L: 58, 94
# L: 59, 85
# hey: 2, 7
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23971 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 3e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 7000.0000000
# Presolve removed 59 rows and 162 columns
# Presolve time: 0.03s
# Presolved: 438 rows, 1326 columns, 20120 nonzeros
# Found heuristic solution: objective 9900.0000000
# Variable types: 0 continuous, 1326 integer (1326 binary)
#
# Root relaxation: objective 2.220444e+03, 609 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2220.44443    0  147 7000.00000 2220.44443  68.3%     -    0s
# H    0     0                    3850.0000000 2220.44443  42.3%     -    0s
# H    0     0                    3150.0000000 2220.44443  29.5%     -    0s
# H    0     0                    2650.0000000 2220.44443  16.2%     -    0s
# H    0     0                    2250.0000000 2220.44443  1.31%     -    0s
#
# Explored 1 nodes (609 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 2250 2650 3150 ... 11900
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.250000000000e+03, best bound 2.250000000000e+03, gap 0.0000%
# L: 35, 105
# L: 39, 99
# L: 40, 109
# L: 46, 100
# L: 47, 108
# L: 52, 100
# L: 53, 107
# L: 58, 99
# L: 60, 110
# hey: 2, 8
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23991 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 3e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 8750.0000000
# Presolve removed 39 rows and 97 columns
# Presolve time: 0.03s
# Presolved: 458 rows, 1391 columns, 21309 nonzeros
# Found heuristic solution: objective 11150.000000
# Found heuristic solution: objective 7250.0000000
# Variable types: 0 continuous, 1391 integer (1391 binary)
#
# Root relaxation: objective 2.465364e+03, 575 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2465.36371    0   73 7250.00000 2465.36371  66.0%     -    0s
# H    0     0                    3350.0000000 2465.36371  26.4%     -    0s
# H    0     0                    2500.0000000 2465.36371  1.39%     -    0s
#
# Explored 1 nodes (575 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 2500 3350 7250 ... 12650
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+03, best bound 2.500000000000e+03, gap 0.0000%
# L: 35, 118
# L: 35, 125
# L: 41, 116
# L: 41, 125
# L: 48, 116
# L: 48, 125
# L: 54, 120
# L: 56, 126
# L: 59, 116
# L: 60, 124
# hey: 2, 9
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23926 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+05, 2e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 7750.0000000
# Presolve removed 104 rows and 275 columns
# Presolve time: 0.03s
# Presolved: 393 rows, 1213 columns, 17681 nonzeros
# Found heuristic solution: objective 9150.0000000
# Found heuristic solution: objective 6000.0000000
# Variable types: 0 continuous, 1213 integer (1213 binary)
#
# Root relaxation: objective 2.026360e+03, 512 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2026.35984    0  138 6000.00000 2026.35984  66.2%     -    0s
# H    0     0                    3100.0000000 2026.35984  34.6%     -    0s
# H    0     0                    2400.0000000 2026.35984  15.6%     -    0s
# H    0     0                    2250.0000000 2026.35984  9.94%     -    0s
# H    0     0                    2150.0000000 2031.63846  5.51%     -    0s
#      0     0     cutoff    0      2150.00000 2150.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#
# Explored 1 nodes (618 simplex iterations) in 0.24 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 2150 2250 2400 ... 10900
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.150000000000e+03, best bound 2.150000000000e+03, gap 0.0000%
# S: 32, 129
# L: 36, 132
# L: 40, 138
# L: 43, 131
# L: 47, 138
# L: 51, 142
# L: 52, 132
# L: 59, 131
# L: 60, 141
# hey: 2, 10
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23721 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+05, 2e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 2750.0000000
# Presolve removed 309 rows and 895 columns
# Presolve time: 0.01s
# Presolved: 188 rows, 593 columns, 7216 nonzeros
# Found heuristic solution: objective 4000.0000000
# Found heuristic solution: objective 2550.0000000
# Variable types: 0 continuous, 593 integer (593 binary)
#
# Root relaxation: objective 1.418098e+03, 265 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1418.09836    0   62 2550.00000 1418.09836  44.4%     -    0s
# H    0     0                    1950.0000000 1418.09836  27.3%     -    0s
# H    0     0                    1500.0000000 1418.09836  5.46%     -    0s
#      0     0 1419.69427    0   62 1500.00000 1419.69427  5.35%     -    0s
#      0     0 1419.69427    0   62 1500.00000 1419.69427  5.35%     -    0s
#      0     0 1423.12669    0   67 1500.00000 1423.12669  5.12%     -    0s
#      0     0 1426.17352    0   68 1500.00000 1426.17352  4.92%     -    0s
#      0     0 1428.27917    0   68 1500.00000 1428.27917  4.78%     -    0s
#      0     0 1430.15270    0   68 1500.00000 1430.15270  4.66%     -    0s
#      0     0 1444.27358    0   68 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   70 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   87 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   73 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   77 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   74 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   74 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   73 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   19 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   11 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   84 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   81 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   37 1500.00000 1444.27358  3.72%     -    0s
#      0     0 1444.27358    0   36 1500.00000 1444.27358  3.72%     -    0s
#      0     0 infeasible    0      1500.00000 1500.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#
# Explored 1 nodes (859 simplex iterations) in 0.31 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1500 1950 2550 ... 5550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+03, best bound 1.500000000000e+03, gap 0.0000%
# L: 36, 155
# L: 44, 156
# L: 51, 148
# L: 52, 155
# L: 59, 147
# L: 59, 155
# hey: 3, 1
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23890 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+04, 6e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 7750.0000000
# Presolve removed 140 rows and 438 columns
# Presolve time: 0.02s
# Presolved: 357 rows, 1050 columns, 15982 nonzeros
# Found heuristic solution: objective 7950.0000000
# Found heuristic solution: objective 6750.0000000
# Variable types: 0 continuous, 1050 integer (1050 binary)
#
# Root relaxation: objective 1.813115e+03, 463 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1813.11489    0   51 6750.00000 1813.11489  73.1%     -    0s
# H    0     0                    2300.0000000 1813.11489  21.2%     -    0s
# H    0     0                    2000.0000000 1813.11489  9.34%     -    0s
#      0     0 1882.13848    0   90 2000.00000 1882.13848  5.89%     -    0s
# H    0     0                    1900.0000000 1882.13848  0.94%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 1 nodes (602 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1900 2000 2300 ... 9250
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+03, best bound 1.900000000000e+03, gap 0.0000%
# L: 65, 14
# L: 66, 7
# L: 71, 13
# L: 74, 9
# L: 82, 8
# L: 83, 14
# L: 89, 8
# S: 93, 14
# hey: 3, 2
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 24017 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+05, 2e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 12750.000000
# Presolve removed 13 rows and 60 columns
# Presolve time: 0.03s
# Presolved: 484 rows, 1428 columns, 22649 nonzeros
# Found heuristic solution: objective 10600.000000
# Variable types: 0 continuous, 1428 integer (1428 binary)
#
# Root relaxation: objective 2.115901e+03, 848 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2115.90083    0  140 10600.0000 2115.90083  80.0%     -    0s
# H    0     0                    3450.0000000 2115.90083  38.7%     -    0s
# H    0     0                    2950.0000000 2115.90083  28.3%     -    0s
# H    0     0                    2250.0000000 2115.90083  5.96%     -    0s
#      0     0 2117.91411    0  150 2250.00000 2117.91411  5.87%     -    0s
#      0     0 2117.91411    0  140 2250.00000 2117.91411  5.87%     -    0s
#      0     0 2117.96417    0  150 2250.00000 2117.96417  5.87%     -    0s
#      0     0 2177.65945    0  273 2250.00000 2177.65945  3.22%     -    0s
#      0     0 2177.83248    0  282 2250.00000 2177.83248  3.21%     -    0s
#      0     0 2177.84195    0  282 2250.00000 2177.84195  3.21%     -    0s
#      0     0 2180.61356    0  269 2250.00000 2180.61356  3.08%     -    1s
#      0     0 2180.66561    0  277 2250.00000 2180.66561  3.08%     -    1s
#      0     0 2181.01143    0  276 2250.00000 2181.01143  3.07%     -    1s
#      0     0 2181.03172    0  275 2250.00000 2181.03172  3.07%     -    1s
#      0     0 2181.06790    0  262 2250.00000 2181.06790  3.06%     -    1s
#      0     0 2181.06811    0  263 2250.00000 2181.06811  3.06%     -    1s
#      0     0 2181.78646    0  278 2250.00000 2181.78646  3.03%     -    1s
#      0     0 2181.87547    0  275 2250.00000 2181.87547  3.03%     -    1s
#      0     0 2182.00430    0  276 2250.00000 2182.00430  3.02%     -    1s
#      0     0 2182.02559    0  281 2250.00000 2182.02559  3.02%     -    1s
#      0     0 2182.02684    0  281 2250.00000 2182.02684  3.02%     -    1s
#      0     0 2182.28689    0  274 2250.00000 2182.28689  3.01%     -    2s
#      0     0 2182.29243    0  282 2250.00000 2182.29243  3.01%     -    2s
#      0     0 2182.29998    0   72 2250.00000 2182.29998  3.01%     -    2s
#      0     0 2182.29998    0   72 2250.00000 2182.29998  3.01%     -    3s
#      0     0 2182.29998    0  140 2250.00000 2182.29998  3.01%     -    3s
#      0     0 2182.29998    0   30 2250.00000 2182.29998  3.01%     -    3s
#      0     0 2192.69910    0  245 2250.00000 2192.69910  2.55%     -    3s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Zero half: 1
#
# Explored 1 nodes (4217 simplex iterations) in 3.49 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 2250 2950 3450 ... 12500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.250000000000e+03, best bound 2.250000000000e+03, gap 0.0000%
# L: 65, 30
# L: 66, 19
# L: 66, 24
# L: 72, 29
# L: 74, 22
# L: 79, 28
# L: 83, 23
# L: 85, 29
# L: 90, 29
# hey: 3, 3
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 24017 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+04, 9e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 10500.000000
# Presolve removed 13 rows and 45 columns
# Presolve time: 0.03s
# Presolved: 484 rows, 1443 columns, 22629 nonzeros
# Found heuristic solution: objective 10800.000000
# Found heuristic solution: objective 9200.0000000
# Variable types: 0 continuous, 1443 integer (1443 binary)
#
# Root relaxation: objective 2.238372e+03, 977 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2238.37177    0  225 9200.00000 2238.37177  75.7%     -    0s
# H    0     0                    3050.0000000 2238.37177  26.6%     -    0s
# H    0     0                    2500.0000000 2238.37177  10.5%     -    0s
#      0     0 2245.48342    0  237 2500.00000 2245.48342  10.2%     -    0s
#      0     0 2245.48342    0  241 2500.00000 2245.48342  10.2%     -    0s
#      0     0 2245.48342    0  241 2500.00000 2245.48342  10.2%     -    0s
#      0     0 2245.48342    0  248 2500.00000 2245.48342  10.2%     -    0s
#      0     0 2245.48342    0  252 2500.00000 2245.48342  10.2%     -    0s
#      0     0 2245.48342    0  252 2500.00000 2245.48342  10.2%     -    0s
#      0     0 2245.49494    0  260 2500.00000 2245.49494  10.2%     -    0s
# H    0     0                    2400.0000000 2245.49494  6.44%     -    1s
#      0     0 2252.21423    0  261 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  225 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  219 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  238 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  249 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  249 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  242 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  253 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  256 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  254 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2252.21423    0  260 2400.00000 2252.21423  6.16%     -    1s
#      0     0 2254.86956    0  250 2400.00000 2254.86956  6.05%     -    1s
#      0     0 2254.86956    0  250 2400.00000 2254.86956  6.05%     -    2s
#      0     2 2254.86956    0  250 2400.00000 2254.86956  6.05%     -    2s
#   1066   608 2303.63028   15  249 2400.00000 2276.27489  5.16%  44.0    5s
#   3444  1005 2307.19440   30  185 2400.00000 2295.43556  4.36%  48.1   10s
#   6104  1835     cutoff   24      2400.00000 2310.66560  3.72%  47.6   16s
#  10768  1073     cutoff   23      2400.00000 2333.94521  2.75%  48.8   20s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 13
#   Zero half: 3
#
# Explored 12330 nodes (581992 simplex iterations) in 20.89 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 2400 2500 3050 ... 12500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+03, best bound 2.400000000000e+03, gap 0.0000%
# S: 63, 38
# L: 65, 46
# L: 66, 34
# L: 67, 40
# L: 72, 45
# L: 74, 35
# L: 75, 41
# L: 81, 36
# L: 82, 42
# L: 89, 34
# hey: 3, 4
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23999 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+04, 6e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 11500.000000
# Presolve removed 31 rows and 82 columns
# Presolve time: 0.03s
# Presolved: 466 rows, 1406 columns, 21723 nonzeros
# Found heuristic solution: objective 11050.000000
# Found heuristic solution: objective 9600.0000000
# Variable types: 0 continuous, 1406 integer (1406 binary)
#
# Root relaxation: objective 2.321567e+03, 758 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2321.56659    0  213 9600.00000 2321.56659  75.8%     -    0s
# H    0     0                    4200.0000000 2321.56659  44.7%     -    0s
# H    0     0                    3300.0000000 2321.56659  29.6%     -    0s
# H    0     0                    2800.0000000 2321.56659  17.1%     -    0s
# H    0     0                    2500.0000000 2321.56659  7.14%     -    0s
#      0     0 2389.02272    0  251 2500.00000 2389.02272  4.44%     -    0s
#      0     0 2389.10214    0  257 2500.00000 2389.10214  4.44%     -    0s
#      0     0 2400.00000    0  249 2500.00000 2400.00000  4.00%     -    0s
#      0     0 2400.00000    0  245 2500.00000 2400.00000  4.00%     -    0s
# H    0     0                    2400.0000000 2400.00000  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 2
#   Zero half: 7
#
# Explored 1 nodes (1026 simplex iterations) in 1.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 2400 2500 2800 ... 12250
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+03, best bound 2.400000000000e+03, gap 0.0000%
# L: 65, 51
# L: 67, 57
# L: 72, 51
# L: 74, 57
# L: 76, 63
# L: 80, 52
# L: 82, 59
# L: 89, 62
# L: 90, 52
# S: 93, 59
# hey: 3, 5
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23939 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+04, 5e+04]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 6000.0000000
# Presolve removed 91 rows and 205 columns
# Presolve time: 0.03s
# Presolved: 406 rows, 1283 columns, 18353 nonzeros
# Found heuristic solution: objective 10100.000000
# Found heuristic solution: objective 5300.0000000
# Variable types: 0 continuous, 1283 integer (1283 binary)
#
# Root relaxation: objective 1.934152e+03, 486 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1934.15156    0   21 5300.00000 1934.15156  63.5%     -    0s
# H    0     0                    2000.0000000 1934.15156  3.29%     -    0s
#      0     0 1936.15506    0   40 2000.00000 1936.15506  3.19%     -    0s
#      0     0 1936.15506    0   20 2000.00000 1936.15506  3.19%     -    0s
#      0     0     cutoff    0      2000.00000 2000.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 1
#
# Explored 1 nodes (815 simplex iterations) in 0.13 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 2000 5300 5500 ... 12400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+03, best bound 2.000000000000e+03, gap 0.0000%
# L: 67, 79
# L: 71, 72
# L: 75, 78
# L: 80, 67
# L: 82, 77
# L: 87, 70
# L: 90, 77
# L: 91, 68
# hey: 3, 6
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 24018 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+05, 2e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 12000.000000
# Presolve removed 12 rows and 48 columns
# Presolve time: 0.03s
# Presolved: 485 rows, 1440 columns, 22790 nonzeros
# Found heuristic solution: objective 10600.000000
# Found heuristic solution: objective 10450.000000
# Variable types: 0 continuous, 1440 integer (1440 binary)
#
# Root relaxation: objective 2.301631e+03, 805 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2301.63120    0  205 10450.0000 2301.63120  78.0%     -    0s
# H    0     0                    4050.0000000 2301.63120  43.2%     -    0s
# H    0     0                    3800.0000000 2301.63120  39.4%     -    0s
# H    0     0                    3050.0000000 2301.63120  24.5%     -    0s
# H    0     0                    2650.0000000 2301.63120  13.1%     -    0s
# H    0     0                    2500.0000000 2301.63120  7.93%     -    0s
#      0     0 2310.67877    0  219 2500.00000 2310.67877  7.57%     -    0s
#      0     0 2328.05858    0  224 2500.00000 2328.05858  6.88%     -    0s
#      0     0 2329.35109    0  258 2500.00000 2329.35109  6.83%     -    0s
# H    0     0                    2400.0000000 2329.35109  2.94%     -    0s
#      0     0 2329.36276    0  259 2400.00000 2329.36276  2.94%     -    0s
#      0     0 2330.60938    0  258 2400.00000 2330.60938  2.89%     -    1s
#      0     0 2330.60938    0  201 2400.00000 2330.60938  2.89%     -    1s
#      0     0 2330.60938    0  193 2400.00000 2330.60938  2.89%     -    1s
#      0     0     cutoff    0      2400.00000 2400.00000  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   Zero half: 10
#
# Explored 1 nodes (2233 simplex iterations) in 1.33 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2400 2500 2650 ... 12500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+03, best bound 2.400000000000e+03, gap 0.0000%
# L: 65, 86
# L: 69, 93
# S: 70, 82
# L: 73, 87
# L: 76, 94
# L: 78, 85
# L: 83, 94
# L: 84, 87
# L: 90, 92
# L: 91, 84
# hey: 3, 7
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 24008 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+05, 5e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 11500.000000
# Presolve removed 22 rows and 73 columns
# Presolve time: 0.03s
# Presolved: 475 rows, 1415 columns, 22259 nonzeros
# Found heuristic solution: objective 9950.0000000
# Found heuristic solution: objective 9500.0000000
# Variable types: 0 continuous, 1415 integer (1415 binary)
#
# Root relaxation: objective 2.232358e+03, 858 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2232.35772    0  221 9500.00000 2232.35772  76.5%     -    0s
# H    0     0                    3550.0000000 2232.35772  37.1%     -    0s
# H    0     0                    3200.0000000 2232.35772  30.2%     -    0s
# H    0     0                    2550.0000000 2232.35772  12.5%     -    0s
# H    0     0                    2250.0000000 2232.35772  0.78%     -    0s
#
# Explored 1 nodes (858 simplex iterations) in 0.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 2250 2550 3200 ... 12500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.250000000000e+03, best bound 2.250000000000e+03, gap 0.0000%
# L: 65, 109
# L: 72, 109
# L: 74, 104
# L: 77, 99
# L: 80, 110
# L: 83, 100
# L: 84, 107
# L: 89, 101
# L: 90, 108
# hey: 3, 8
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 24013 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+05, 4e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 12750.000000
# Presolve removed 17 rows and 59 columns
# Presolve time: 0.03s
# Presolved: 480 rows, 1429 columns, 22364 nonzeros
# Found heuristic solution: objective 10900.000000
# Found heuristic solution: objective 10200.000000
# Variable types: 0 continuous, 1429 integer (1429 binary)
#
# Root relaxation: objective 2.341791e+03, 751 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2341.79130    0  142 10200.0000 2341.79130  77.0%     -    0s
# H    0     0                    3800.0000000 2341.79130  38.4%     -    0s
# H    0     0                    3350.0000000 2341.79130  30.1%     -    0s
# H    0     0                    2500.0000000 2341.79130  6.33%     -    0s
#      0     0 2423.54327    0  209 2500.00000 2423.54327  3.06%     -    0s
#      0     0 2423.54327    0  142 2500.00000 2423.54327  3.06%     -    0s
#      0     0 2425.57246    0  239 2500.00000 2425.57246  2.98%     -    0s
#      0     0 2426.08612    0  231 2500.00000 2426.08612  2.96%     -    0s
#      0     0 2433.19590    0  198 2500.00000 2433.19590  2.67%     -    0s
#      0     0 2433.94394    0  193 2500.00000 2433.94394  2.64%     -    0s
#      0     0 2434.13536    0  199 2500.00000 2434.13536  2.63%     -    0s
#      0     0 2434.36650    0  196 2500.00000 2434.36650  2.63%     -    0s
#      0     0 2434.62982    0  201 2500.00000 2434.62982  2.61%     -    0s
#      0     0 2434.66169    0  199 2500.00000 2434.66169  2.61%     -    0s
#      0     0 2434.66332    0  198 2500.00000 2434.66332  2.61%     -    0s
#      0     0 2435.23611    0  205 2500.00000 2435.23611  2.59%     -    1s
#      0     0 2435.24710    0  207 2500.00000 2435.24710  2.59%     -    1s
#      0     0 2435.32958    0  206 2500.00000 2435.32958  2.59%     -    1s
#      0     0 2435.34096    0  208 2500.00000 2435.34096  2.59%     -    1s
#      0     0 2435.35974    0  218 2500.00000 2435.35974  2.59%     -    1s
# ...
# Best objective 1.400000000000e+03, best bound 1.400000000000e+03, gap 0.0000%
# L: 252, 105
# L: 252, 110
# L: 256, 100
# L: 259, 109
# L: 262, 102
# S: 263, 112
# hey: 9, 8
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23932 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+05, 4e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 8500.0000000
# Presolve removed 98 rows and 297 columns
# Presolve time: 0.03s
# Presolved: 399 rows, 1191 columns, 17899 nonzeros
# Found heuristic solution: objective 8750.0000000
# Found heuristic solution: objective 6900.0000000
# Variable types: 0 continuous, 1191 integer (1191 binary)
#
# Root relaxation: objective 1.793077e+03, 605 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1793.07669    0   60 6900.00000 1793.07669  74.0%     -    0s
# H    0     0                    2350.0000000 1793.07669  23.7%     -    0s
# H    0     0                    2150.0000000 1793.07669  16.6%     -    0s
# H    0     0                    2000.0000000 1793.07669  10.3%     -    0s
#      0     0 1878.70811    0  160 2000.00000 1878.70811  6.06%     -    0s
# H    0     0                    1900.0000000 1878.70811  1.12%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (774 simplex iterations) in 0.15 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1900 2000 2150 ... 10900
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+03, best bound 1.900000000000e+03, gap 0.0000%
# L: 251, 116
# L: 257, 116
# L: 258, 126
# L: 264, 115
# L: 266, 125
# L: 270, 120
# L: 274, 125
# S: 278, 128
# hey: 9, 9
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23807 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+05, 4e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 7000.0000000
# Presolve removed 223 rows and 689 columns
# Presolve time: 0.02s
# Presolved: 274 rows, 799 columns, 11398 nonzeros
# Found heuristic solution: objective 5900.0000000
# Found heuristic solution: objective 5600.0000000
# Variable types: 0 continuous, 799 integer (799 binary)
#
# Root relaxation: objective 1.599403e+03, 367 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1599.40256    0   41 5600.00000 1599.40256  71.4%     -    0s
# H    0     0                    2050.0000000 1599.40256  22.0%     -    0s
# H    0     0                    2000.0000000 1599.40256  20.0%     -    0s
# H    0     0                    1750.0000000 1599.40256  8.61%     -    0s
#      0     0 1661.61268    0  107 1750.00000 1661.61268  5.05%     -    0s
#      0     0 1661.61268    0   41 1750.00000 1661.61268  5.05%     -    0s
#      0     0 1661.61268    0   35 1750.00000 1661.61268  5.05%     -    0s
#      0     0 1661.61268    0   43 1750.00000 1661.61268  5.05%     -    0s
#      0     0 1661.61268    0   45 1750.00000 1661.61268  5.05%     -    0s
#      0     0 1661.61268    0  103 1750.00000 1661.61268  5.05%     -    0s
#      0     0 1666.51273    0  102 1750.00000 1666.51273  4.77%     -    0s
#      0     0 1667.16787    0  101 1750.00000 1667.16787  4.73%     -    0s
#      0     0 1669.56306    0  126 1750.00000 1669.56306  4.60%     -    0s
#      0     0 1670.12790    0  141 1750.00000 1670.12790  4.56%     -    0s
#      0     0 1670.41340    0  135 1750.00000 1670.41340  4.55%     -    0s
#      0     0 1670.54040    0  133 1750.00000 1670.54040  4.54%     -    0s
#      0     0 1671.61190    0  129 1750.00000 1671.61190  4.48%     -    0s
#      0     0 1671.64624    0  131 1750.00000 1671.64624  4.48%     -    0s
#      0     0 1671.86059    0  135 1750.00000 1671.86059  4.47%     -    0s
#      0     0 1671.86808    0  152 1750.00000 1671.86808  4.46%     -    0s
#      0     0 1672.80995    0  151 1750.00000 1672.80995  4.41%     -    0s
#      0     0 1673.02861    0  155 1750.00000 1673.02861  4.40%     -    0s
#      0     0 1673.09091    0  148 1750.00000 1673.09091  4.39%     -    0s
#      0     0 1673.26779    0  147 1750.00000 1673.26779  4.38%     -    0s
#      0     0 1673.30716    0  150 1750.00000 1673.30716  4.38%     -    0s
#      0     0 1673.32854    0  158 1750.00000 1673.32854  4.38%     -    0s
#      0     0 1673.44841    0  153 1750.00000 1673.44841  4.37%     -    0s
#      0     0 1673.51870    0  153 1750.00000 1673.51870  4.37%     -    0s
#      0     0 1673.52339    0  155 1750.00000 1673.52339  4.37%     -    0s
#      0     0 1673.76185    0  146 1750.00000 1673.76185  4.36%     -    0s
#      0     0 1673.79467    0  145 1750.00000 1673.79467  4.35%     -    0s
#      0     0 1673.87285    0  159 1750.00000 1673.87285  4.35%     -    0s
#      0     0 1673.87285    0  159 1750.00000 1673.87285  4.35%     -    0s
#      0     2 1673.87285    0  159 1750.00000 1673.87285  4.35%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 6
#   Zero half: 14
#
# Explored 450 nodes (19247 simplex iterations) in 1.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1750 2000 2050 ... 7000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.750000000000e+03, best bound 1.750000000000e+03, gap 0.0000%
# L: 252, 131
# L: 252, 136
# L: 259, 132
# L: 265, 134
# L: 270, 130
# L: 271, 135
# L: 276, 131
# hey: 9, 10
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 1
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 2
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 3
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 4
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 5
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 6
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 7
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# hey: 10, 8
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23622 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 3250.0000000
# Presolve removed 408 rows and 1241 columns
# Presolve time: 0.01s
# Presolved: 89 rows, 247 columns, 2666 nonzeros
# Found heuristic solution: objective 2150.0000000
# Variable types: 0 continuous, 247 integer (247 binary)
#
# Root relaxation: objective 7.246915e+02, 116 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  724.69150    0   43 2150.00000  724.69150  66.3%     -    0s
# H    0     0                     900.0000000  724.69150  19.5%     -    0s
# H    0     0                     750.0000000  724.69150  3.37%     -    0s
#
# Explored 1 nodes (116 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 750 900 2150 ... 3000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.500000000000e+02, best bound 7.500000000000e+02, gap 0.0000%
# L: 283, 125
# L: 290, 127
# L: 298, 128
# hey: 10, 9
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23646 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 3e+05]
# Found heuristic solution: objective 13000.000000
# Found heuristic solution: objective 4250.0000000
# Presolve removed 385 rows and 1159 columns
# Presolve time: 0.01s
# Presolved: 112 rows, 329 columns, 3676 nonzeros
# Found heuristic solution: objective 2750.0000000
# Found heuristic solution: objective 2600.0000000
# Variable types: 0 continuous, 329 integer (329 binary)
#
# Root relaxation: objective 9.621411e+02, 132 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  962.14107    0   26 2600.00000  962.14107  63.0%     -    0s
# H    0     0                    1150.0000000  962.14107  16.3%     -    0s
# H    0     0                    1000.0000000  962.14107  3.79%     -    0s
#
# Explored 1 nodes (132 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1000 1150 2600 ... 3650
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+03, best bound 1.000000000000e+03, gap 0.0000%
# L: 283, 131
# L: 284, 136
# L: 291, 132
# L: 298, 129
# hey: 10, 10
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 497 rows, 1488 columns and 23534 nonzeros
# Variable types: 0 continuous, 1488 integer (1488 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 497 rows and 1488 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# sum = 154649.99990542064

# %%
print("objective value = ", s)
# Out:
# objective value = 154649.99990542064
